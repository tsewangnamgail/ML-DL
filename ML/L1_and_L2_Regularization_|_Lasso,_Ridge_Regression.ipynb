# %% [markdown]
# <a href="https://colab.research.google.com/github/tsewangnamgail/ML-DL/blob/main/ML/L1_and_L2_Regularization_%7C_Lasso%2C_Ridge_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screen Shot 2025-01-13 at 4.17.47 PM.png](data:image/png;base64,...)
# ![Screen Shot 2025-01-13 at 4.29.57 PM.png](data:image/png;base64,...)
# ![Screen Shot 2025-01-13 at 4.30.11 PM.png](data:image/png;base64,...)

# %% [markdown]
# #L1 and L2 regularization

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv('california_housing_train.csv')
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
dataset.nunique()
# Out:
# longitude               827
# latitude                840
# housing_median_age       52
# total_rooms            5533
# total_bedrooms         1848
# population             3683
# households             1740
# median_income         11175
# median_house_value     3694
# dtype: int64

# %%
dataset.shape
# Out:
# (17000, 9)

# %%
dataset.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
''' if ther is nan values fill it with values
like 0 or mean and if there are values in character
form convert it into integer from with the help of get_dummies.'''
# Out:
# ' if ther is nan values fill it with values \nlike 0 or mean and if there are values in character \nform convert it into integer from with the help of get_dummies.'

# %%
X = dataset.drop('median_house_value', axis=1)
y = dataset['median_house_value']
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression().fit(train_X,train_y)

# %%
reg.score(test_X,test_y)
# Out:
# 0.6492538345819182

# %%
reg.score(train_X,train_y)
# Out:
# 0.6375851309751236

# %%
from sklearn import linear_model
lasso_reg=linear_model.Lasso(alpha=50,max_iter=100,tol=0.1)
lasso_reg.fit(train_X,train_y)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
reg.score(test_X,test_y)
# Out:
# 0.6492538345819182

# %%
reg.score(train_X,train_y)
# Out:
# 0.6375851309751236

# %%
from sklearn.linear_model import Ridge
ridge_reg= Ridge(alpha=50,max_iter=100,tol=0.1)
ridge_reg.fit(train_X,train_y)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
reg.score(test_X,test_y)
# Out:
# 0.6492538345819182

# %%
reg.score(train_X,train_y)
# Out:
# 0.6375851309751236
